# %% [markdown]
# <a href="https://colab.research.google.com/github/malakkkk4/Titanic/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,VotingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import KFold,cross_val_score, train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix,  accuracy_score, precision_score,recall_score,classification_report

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
test.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
for col in train.columns:
  print(f'The column: {col}\nvalues_count:\n{train[col].value_counts()}\n\n')
# Out:
# The column: PassengerId
# values_count:
# PassengerId
# 891    1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 16     1
# 15     1
# 14     1
# 13     1
# 12     1
# Name: count, Length: 891, dtype: int64
#
#
# The column: Survived
# values_count:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
#
# The column: Pclass
# values_count:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
#
# The column: Name
# values_count:
# Name
# Dooley, Mr. Patrick                                    1
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
#                                                       ..
# Hewlett, Mrs. (Mary D Kingcome)                        1
# Vestrom, Miss. Hulda Amanda Adolfina                   1
# ...

# %%
for col in test.columns:
  print(f'The column: {col}\nvalues_count:\n{test[col].value_counts()}\n\n')
# Out:
# The column: PassengerId
# values_count:
# PassengerId
# 1309    1
# 892     1
# 1293    1
# 1292    1
# 1291    1
#        ..
# 898     1
# 897     1
# 896     1
# 895     1
# 894     1
# Name: count, Length: 418, dtype: int64
#
#
# The column: Pclass
# values_count:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64
#
#
# The column: Name
# values_count:
# Name
# Peter, Master. Michael J                        1
# Kelly, Mr. James                                1
# Gale, Mr. Harry                                 1
# Bonnell, Miss. Caroline                         1
# Conlon, Mr. Thomas Henry                        1
#                                                ..
# Connolly, Miss. Kate                            1
# Svensson, Mr. Johan Cervin                      1
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# Wirz, Mr. Albert                                1
# Myles, Mr. Thomas Francis                       1
# Name: count, Length: 418, dtype: int64
# ...

# %%
train.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_92a05_row0_col0, #T_92a05_row0_col1, #T_92a05_row0_col2, #T_92a05_row0_col3, #T_92a05_row0_col4, #T_92a05_row0_col5, #T_92a05_row0_col6, #T_92a05_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_92a05_row1_col0, #T_92a05_row5_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_92a05_row1_col1, #T_92a05_row1_col2, #T_92a05_row1_col4, #T_92a05_row1_col5, #T_92a05_row2_col1, #T_92a05_row2_col2, #T_92a05_row2_col4, #T_92a05_row2_col5, #T_92a05_row3_col0, #T_92a05_row3_col1, #T_92a05_row3_col2, #T_92a05_row3_col3, #T_92a05_row3_col4, #T_92a05_row3_col5, #T_92a05_row3_col6, #T_92a05_row4_col1, #T_92a05_row4_col2, #T_92a05_row4_col4, #T_92a05_row4_col5, #T_92a05_row5_col1, #T_92a05_row5_col2, #T_92a05_row5_col4, #T_92a05_row5_col5, #T_92a05_row6_col1, #T_92a05_row6_col2, #T_92a05_row6_col4, #T_92a05_row6_col5, #T_92a05_row7_col1, #T_92a05_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# ...

# %%
test.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fcc4a_row0_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_fcc4a_row0_col1, #T_fcc4a_row0_col2, #T_fcc4a_row0_col3, #T_fcc4a_row0_col4, #T_fcc4a_row7_col0, #T_fcc4a_row7_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fcc4a_row0_col5 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_fcc4a_row1_col0, #T_fcc4a_row5_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_fcc4a_row1_col1, #T_fcc4a_row1_col3, #T_fcc4a_row1_col4, #T_fcc4a_row2_col0, #T_fcc4a_row2_col1, #T_fcc4a_row2_col3, #T_fcc4a_row2_col4, #T_fcc4a_row3_col1, #T_fcc4a_row3_col2, #T_fcc4a_row3_col3, #T_fcc4a_row3_col4, #T_fcc4a_row3_col5, #T_fcc4a_row4_col1, #T_fcc4a_row4_col3, #T_fcc4a_row4_col4, #T_fcc4a_row5_col3, #T_fcc4a_row5_col4, #T_fcc4a_row6_col3, #T_fcc4a_row6_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fcc4a_row1_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_fcc4a_row1_col5 {
# ...

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %%
test.duplicated().sum()
# Out:
# np.int64(0)

# %%
def bar_chart(feature):
  survived=train[train['Survived']==1][feature].value_counts()
  dead=train[train['Survived']==0][feature].value_counts()
  df=pd.DataFrame([survived,dead])
  df.index=['Survived','Dead']
  df.plot(kind='bar',stacked=True,figsize=(10,6))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
bar_chart('Embarked')

# %%
train_test_data=[train,test]
for dataset in train_test_data:
  dataset['Title']=dataset['Name'].str.extract(' ([A-Za-z]+).',expand=False)

# %%
train['Title'].value_counts()
# Out:
# Title
# Mr             502
# Miss           179
# Mrs            121
# Master          40
# Dr               7
# Rev              6
# y                4
# Planke           3
# Impe             3
# Mlle             2
# Gordon           2
# Major            2
# Col              2
# der              1
# Don              1
# Steen            1
# Mulder           1
# Pelsmaeker       1
# Walle            1
# Billiard         1
# Ms               1
# Carlo            1
# Mme              1
# Messemaeker      1
# Capt             1
# Velde            1
# the              1
# Shawah           1
# Jonkheer         1
# Melkebeke        1
# Cruyssen         1
# Name: count, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Title
# Mr             234
# Miss            77
# Mrs             70
# Master          19
# y                4
# Billiard         2
# Rev              2
# Col              2
# Ms               1
# Khalil           1
# Carlo            1
# Palmquist        1
# Planke           1
# Messemaeker      1
# Dr               1
# Brito            1
# Name: count, dtype: int64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
bar_chart('Title')

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
title_mapping = {
    "Mr": 0, "Miss": 1, "Mrs": 2,
    "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3,
    "Mlle": 3, "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3,
    "Mme": 3, "Capt": 3, "Sir": 3
}

for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)   # map known titles
    dataset['Title'] = dataset['Title'].fillna(3)            # replace NaN with "Rare" category
    dataset['Title'] = dataset['Title'].astype(int)          # now safe to cast to int

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
bar_chart('Title')

# %%
train.drop('Name',axis=1,inplace=True)
test.drop('Name',axis=1,inplace=True)

# %%
sex_mapping={'male':0,'female':1}
for dataset in train_test_data:
  dataset['Sex']=dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %%
imputer=SimpleImputer(strategy='mean')
train['Age']=imputer.fit_transform(train[['Age']])
test['Age']=imputer.fit_transform(test[['Age']])
train['Age']=train['Age'].astype(int)
test['Age']=test['Age'].astype(int)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0   22      1      0         A/5 21171
# 1              2         1       1    1   38      1      0          PC 17599
# 2              3         1       3    1   26      0      0  STON/O2. 3101282
# 3              4         1       1    1   35      1      0            113803
# 4              5         0       3    0   35      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0   27      0      0            211536
# 887          888         1       1    1   19      0      0            112053
# 888          889         0       3    1   29      1      2        W./C. 6607
# 889          890         1       1    0   26      0      0            111369
# 890          891         0       3    0   32      0      0            370376
#
#         Fare Cabin Embarked  Title
# ...

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# dtype: int64

# %%
for dataset in train_test_data:
    dataset.drop('Cabin', axis=1, inplace=True)

# %%
dataset.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# Title          0
# dtype: int64

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.show()

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.xlim(0,20)
plt.show()

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.xlim(20,30)
plt.show()

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Age',shade=True)
facet.set(xlim=(0,train['Age'].max()))
facet.add_legend()
plt.xlim(20,40)
plt.show()

# %%
for dataset in train_test_data:
  dataset.loc[dataset['Age']<=16,'Age']=0
  dataset.loc[(dataset['Age']>16) & (dataset['Age']<=26),'Age']=1
  dataset.loc[(dataset['Age']>26) & (dataset['Age']<=34),'Age']=2
  dataset.loc[(dataset['Age']>34) & (dataset['Age']<=40),'Age']=3
  dataset.loc[(dataset['Age']>40) & (dataset['Age']<=62),'Age']=4
  dataset.loc[dataset['Age']>62,'Age']=5

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0    1      1      0         A/5 21171
# 1              2         1       1    1    3      1      0          PC 17599
# 2              3         1       3    1    1      0      0  STON/O2. 3101282
# 3              4         1       1    1    3      1      0            113803
# 4              5         0       3    0    3      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0    2      0      0            211536
# 887          888         1       1    1    1      0      0            112053
# 888          889         0       3    1    2      1      2        W./C. 6607
# 889          890         1       1    0    1      0      0            111369
# 890          891         0       3    0    2      0      0            370376
#
#         Fare Embarked  Title
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['Embarked'] = le.fit_transform(train['Embarked'])
test['Embarked'] = le.transform(test['Embarked'])

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0    1      1      0         A/5 21171
# 1              2         1       1    1    3      1      0          PC 17599
# 2              3         1       3    1    1      0      0  STON/O2. 3101282
# 3              4         1       1    1    3      1      0            113803
# 4              5         0       3    0    3      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0    2      0      0            211536
# 887          888         1       1    1    1      0      0            112053
# 888          889         0       3    1    2      1      2        W./C. 6607
# 889          890         1       1    0    1      0      0            111369
# 890          891         0       3    0    2      0      0            370376
#
#         Fare  Embarked  Title
# ...

# %%
test
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch              Ticket  \
# 0            892       3    0    2      0      0              330911
# 1            893       3    1    4      1      0              363272
# 2            894       2    0    4      0      0              240276
# 3            895       3    0    2      0      0              315154
# 4            896       3    1    1      1      1             3101298
# ..           ...     ...  ...  ...    ...    ...                 ...
# 413         1305       3    0    2      0      0           A.5. 3236
# 414         1306       1    1    3      0      0            PC 17758
# 415         1307       3    0    3      0      0  SOTON/O.Q. 3101262
# 416         1308       3    0    2      0      0              359309
# 417         1309       3    0    2      1      1                2668
#
#          Fare  Embarked  Title
# 0      7.8292         1      0
# 1      7.0000         2      2
# 2      9.6875         1      0
# ...

# %%
test['Fare'].fillna(test.groupby('Pclass')['Fare'].transform('median'),inplace=True)

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Fare',shade=True)
facet.set(xlim=(0,train['Fare'].max()))
facet.add_legend()
plt.show()

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Fare',shade=True)
facet.set(xlim=(0,train['Fare'].max()))
facet.add_legend()
plt.xlim(0,20)
plt.show()

# %%
facet=sns.FacetGrid(train,hue='Survived',aspect=4)
facet.map(sns.kdeplot,'Fare',shade=True)
facet.set(xlim=(0,train['Fare'].max()))
facet.add_legend()
plt.xlim(30,100)
plt.show()

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0    1      1      0         A/5 21171
# 1              2         1       1    1    3      1      0          PC 17599
# 2              3         1       3    1    1      0      0  STON/O2. 3101282
# 3              4         1       1    1    3      1      0            113803
# 4              5         0       3    0    3      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0    2      0      0            211536
# 887          888         1       1    1    1      0      0            112053
# 888          889         0       3    1    2      1      2        W./C. 6607
# 889          890         1       1    0    1      0      0            111369
# 890          891         0       3    0    2      0      0            370376
#
#         Fare  Embarked  Title
# ...

# %%
#Binnig
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0    1      1      0         A/5 21171
# 1              2         1       1    1    3      1      0          PC 17599
# 2              3         1       3    1    1      0      0  STON/O2. 3101282
# 3              4         1       1    1    3      1      0            113803
# 4              5         0       3    0    3      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0    2      0      0            211536
# 887          888         1       1    1    1      0      0            112053
# 888          889         0       3    1    2      1      2        W./C. 6607
# 889          890         1       1    0    1      0      0            111369
# 890          891         0       3    0    2      0      0            370376
#
#      Fare  Embarked  Title
# ...

# %%
test
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch              Ticket  Fare  \
# 0            892       3    0    2      0      0              330911   0.0
# 1            893       3    1    4      1      0              363272   0.0
# 2            894       2    0    4      0      0              240276   0.0
# 3            895       3    0    2      0      0              315154   0.0
# 4            896       3    1    1      1      1             3101298   0.0
# ..           ...     ...  ...  ...    ...    ...                 ...   ...
# 413         1305       3    0    2      0      0           A.5. 3236   0.0
# 414         1306       1    1    3      0      0            PC 17758   3.0
# 415         1307       3    0    3      0      0  SOTON/O.Q. 3101262   0.0
# 416         1308       3    0    2      0      0              359309   0.0
# 417         1309       3    0    2      1      1                2668   1.0
#
#      Embarked  Title
# 0           1      0
# 1           2      2
# ...

# %%
train['FamilySize']=train['SibSp']+train['Parch']+1
test['FamilySize']=test['SibSp']+test['Parch']+1

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0    1      1      0         A/5 21171
# 1              2         1       1    1    3      1      0          PC 17599
# 2              3         1       3    1    1      0      0  STON/O2. 3101282
# 3              4         1       1    1    3      1      0            113803
# 4              5         0       3    0    3      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0    2      0      0            211536
# 887          888         1       1    1    1      0      0            112053
# 888          889         0       3    1    2      1      2        W./C. 6607
# 889          890         1       1    0    1      0      0            111369
# 890          891         0       3    0    2      0      0            370376
#
#      Fare  Embarked  Title  FamilySize
# ...

# %%
test
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch              Ticket  Fare  \
# 0            892       3    0    2      0      0              330911   0.0
# 1            893       3    1    4      1      0              363272   0.0
# 2            894       2    0    4      0      0              240276   0.0
# 3            895       3    0    2      0      0              315154   0.0
# 4            896       3    1    1      1      1             3101298   0.0
# ..           ...     ...  ...  ...    ...    ...                 ...   ...
# 413         1305       3    0    2      0      0           A.5. 3236   0.0
# 414         1306       1    1    3      0      0            PC 17758   3.0
# 415         1307       3    0    3      0      0  SOTON/O.Q. 3101262   0.0
# 416         1308       3    0    2      0      0              359309   0.0
# 417         1309       3    0    2      1      1                2668   1.0
#
#      Embarked  Title  FamilySize
# 0           1      0           1
# ...

# %%
features_drop=['Ticket','SibSp','Parch']
train=train.drop(features_drop,axis=1)
test=test.drop(features_drop,axis=1)

# %%
train=train.drop(['PassengerId'],axis=1)

# %%
train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Embarked      0
# Title         0
# FamilySize    0
# dtype: int64

# %%
train.corr()['Survived']
# Out:
# Survived      1.000000
# Pclass       -0.338481
# Sex           0.543351
# Age          -0.046373
# Fare          0.292884
# Embarked     -0.163517
# Title         0.396799
# FamilySize    0.016639
# Name: Survived, dtype: float64

# %%
train_data=train.drop('Survived',axis=1)
target=train['Survived']
train_data.shape, target.shape
# Out:
# ((891, 7), (891,))

# %%
k_fold=KFold(n_splits=5,shuffle=True,random_state=42)

# %%
Knn=KNeighborsClassifier(n_neighbors=9,p=2,metric='minkowski')
scoring='accuracy'
score=cross_val_score(Knn,train_data,target,cv=k_fold,scoring=scoring)
print(score)
# Out:
# [0.81564246 0.79775281 0.84831461 0.76404494 0.82022472]

# %%
KNN_cross=round(np.mean(score)*100,2)
KNN_cross
# Out:
# np.float64(80.92)

# %%
clf2=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=42)
scoring='accuracy'
score2=cross_val_score(clf2,train_data,target,cv=k_fold,scoring=scoring)
print(score2)
# Out:
# [0.81005587 0.80337079 0.85955056 0.76404494 0.83707865]

# %%
DT_cross=round(np.mean(score2)*100,2)
DT_cross
# Out:
# np.float64(81.48)

# %%
clf3=RandomForestClassifier(n_estimators=100,criterion="entropy",max_depth=5,random_state=42)
scoring='accuracy'
score3=cross_val_score(clf3,train_data,target,cv=k_fold,scoring=scoring)
print(score3)
# Out:
# [0.81005587 0.8258427  0.87078652 0.79213483 0.84269663]

# %%
RF_cross=round(np.mean(score3)*100,2)
RF_cross
# Out:
# np.float64(82.83)

# %%
clf4=GaussianNB()
scoring='accuracy'
score4=cross_val_score(clf4,train_data,target,cv=k_fold,scoring=scoring)
print(score4)
# Out:
# [0.7877095  0.80898876 0.82022472 0.76966292 0.80337079]

# %%
NB_cross=round(np.mean(score4)*100,2)
NB_cross
# Out:
# np.float64(79.8)

# %%
Logist=LogisticRegression()
scoring='accuracy'
score5=cross_val_score(Logist,train_data,target,cv=k_fold,scoring=scoring)
print(score5)
# Out:
# [0.79888268 0.82022472 0.85955056 0.78089888 0.83707865]

# %%
log_cross=round(np.mean(score5)*100,2)
log_cross
# Out:
# np.float64(81.93)

# %%
clf5=SVC(kernel='rbf',random_state=42)
scoring='accuracy'
score6=cross_val_score(clf5,train_data,target,cv=k_fold,scoring=scoring)
print(score6)
# Out:
# [0.81005587 0.82022472 0.84831461 0.78651685 0.8258427 ]

# %%
SVM_cross=round(np.mean(score6)*100,2)
SVM_cross
# Out:
# np.float64(81.82)

# %%
gbc=GradientBoostingClassifier(n_estimators=100,learning_rate=0.01,max_depth=4,random_state=42)
scoring='accuracy'
score7=cross_val_score(gbc,train_data,target,cv=k_fold,scoring=scoring)
print(score7)
# Out:
# [0.81005587 0.81460674 0.85955056 0.80337079 0.83707865]

# %%
GB_cross=round(np.mean(score7)*100,2)
GB_cross
# Out:
# np.float64(82.49)

# %%
clf6=AdaBoostClassifier(n_estimators=100,random_state=42)
scoring='accuracy'
score8=cross_val_score(clf6,train_data,target,cv=k_fold,scoring=scoring)
print(score8)
# Out:
# [0.81005587 0.80898876 0.8258427  0.75842697 0.84831461]

# %%
Ada_cross=round(np.mean(score8)*100,2)
Ada_cross
# Out:
# np.float64(81.03)

# %%
clf7=XGBClassifier(n_estimators=100,learning_rate=0.01,max_depth=4,random_state=42)
scoring='accuracy'
score9=cross_val_score(clf7,train_data,target,cv=k_fold,scoring=scoring)
print(score9)
# Out:
# [0.81005587 0.80337079 0.85955056 0.79775281 0.83707865]

# %%
XGB_cross=round(np.mean(score9)*100,2)
XGB_cross
# Out:
# np.float64(82.16)

# %%
model1=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=42)
model2=XGBClassifier(n_estimators=100,learning_rate=0.01,max_depth=4,random_state=42)
model3=RandomForestClassifier(n_estimators=100,criterion="entropy",max_depth=5,random_state=42)

# %%
v_clf55=VotingClassifier(estimators=[('dt',model1),('xgb',model2),('rf',model3)],voting='hard')

# %%
scoring='accuracy'
score10=cross_val_score(v_clf55,train_data,target,cv=k_fold,scoring=scoring)
print(score10)
# Out:
# [0.81005587 0.81460674 0.86516854 0.78651685 0.84269663]

# %%
voting_cross=round(np.mean(score10)*100,2)
voting_cross
# Out:
# np.float64(82.38)

# %%
models_scores = {
    'KNN':KNN_cross,
    'Decision Tree':DT_cross,
    'Random Forest':RF_cross,
    'Naive Bayes':NB_cross,
    'Logistic Regression':log_cross,
    'SVM':SVM_cross,
    'Gradient Boosting':GB_cross,
    'AdaBoost':Ada_cross,
    'XGBoost':XGB_cross,
    'Voting Classifier':voting_cross
}
df_scores=pd.DataFrame(list(models_scores.items()),columns=['Model','Score'])
df_scores=df_scores.sort_values(by='Score',ascending=False)
df_scores
# Out:
#                  Model  Score
# 2        Random Forest  82.83
# 6    Gradient Boosting  82.49
# 9    Voting Classifier  82.38
# 8              XGBoost  82.16
# 4  Logistic Regression  81.93
# 5                  SVM  81.82
# 1        Decision Tree  81.48
# 7             AdaBoost  81.03
# 0                  KNN  80.92
# 3          Naive Bayes  79.80

# %%
x=train.drop('Survived',axis=1)
y=train['Survived']

# %%
x__train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
LogR=LogisticRegression()
LogR.fit(x__train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LogR.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[133,  24],
#        [ 27,  84]])

# %%
LogR_t=accuracy_score(y_test,y_pred)*100
LogR_t
# Out:
# 80.97014925373134

# %%
print(LogR.score(x__train,y_train))
print(LogR.score(x_test,y_test))
# Out:
# 0.8282504012841091
# 0.8097014925373134

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       157
#            1       0.78      0.76      0.77       111
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.80      0.80       268
# weighted avg       0.81      0.81      0.81       268

# %%
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(x__train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[127,  30],
#        [ 31,  80]])

# %%
knn_t=accuracy_score(y_test,y_pred)*100
knn_t
# Out:
# 77.23880597014924

# %%
print(knn.score(x__train,y_train))
print(knn.score(x_test,y_test))
# Out:
# 0.8475120385232745
# 0.7723880597014925

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       157
#            1       0.73      0.72      0.72       111
#
#     accuracy                           0.77       268
#    macro avg       0.77      0.76      0.77       268
# weighted avg       0.77      0.77      0.77       268

# %%
NB = GaussianNB()
NB.fit(x__train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=NB.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[123  34]
#  [ 21  90]]

# %%
NB_t= accuracy_score(y_test, y_pred)*100
NB_t
# Out:
# 79.47761194029852

# %%
print(NB.score(x__train , y_train)*100)
print(NB.score(x_test , y_test)*100)
# Out:
# 80.41733547351525
# 79.47761194029852

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.82       157
#            1       0.73      0.81      0.77       111
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.80      0.79       268
# weighted avg       0.80      0.79      0.80       268

# %%
svml=SVC(kernel='rbf',random_state=42)
svml.fit(x__train,y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred=svml.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[137,  20],
#        [ 28,  83]])

# %%
svm_t=accuracy_score(y_test,y_pred)*100
svm_t
# Out:
# 82.08955223880598

# %%
print(svml.score(x__train,y_train))
print(svml.score(x_test,y_test))
# Out:
# 0.8314606741573034
# 0.8208955223880597

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       157
#            1       0.81      0.75      0.78       111
#
#     accuracy                           0.82       268
#    macro avg       0.82      0.81      0.81       268
# weighted avg       0.82      0.82      0.82       268

# %%
Dtc=DecisionTreeClassifier(criterion='entropy',max_depth=4,random_state=42)
Dtc.fit(x__train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42)

# %%
y_pred=Dtc.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[145,  12],
#        [ 39,  72]])

# %%
Dtx_t=accuracy_score(y_test,y_pred)*100
Dtx_t
# Out:
# 80.97014925373134

# %%
print(Dtc.score(x__train,y_train))
print(Dtc.score(x_test,y_test))
# Out:
# 0.8426966292134831
# 0.8097014925373134

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       157
#            1       0.86      0.65      0.74       111
#
#     accuracy                           0.81       268
#    macro avg       0.82      0.79      0.79       268
# weighted avg       0.82      0.81      0.80       268

# %%
Rf=RandomForestClassifier(n_estimators=100,criterion="entropy",max_depth=5,random_state=42)
Rf.fit(x__train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, random_state=42)

# %%
y_pred=Rf.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[139,  18],
#        [ 34,  77]])

# %%
Rf_t=accuracy_score(y_test,y_pred)*100
Rf_t
# Out:
# 80.59701492537313

# %%
print(Rf.score(x__train,y_train))
print(Rf.score(x_test,y_test))
# Out:
# 0.8571428571428571
# 0.8059701492537313

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       157
#            1       0.81      0.69      0.75       111
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.79      0.79       268
# weighted avg       0.81      0.81      0.80       268

# %%
xgb=XGBClassifier(n_estimators=100,learning_rate=0.01,max_depth=4,random_state=42)
xgb.fit(x__train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=xgb.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[146,  11],
#        [ 39,  72]])

# %%
xgb_t=accuracy_score(y_test,y_pred)*100
xgb_t
# Out:
# 81.34328358208955

# %%
print(xgb.score(x__train,y_train))
print(xgb.score(x_test,y_test))
# Out:
# 0.841091492776886
# 0.8134328358208955

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       157
#            1       0.87      0.65      0.74       111
#
#     accuracy                           0.81       268
#    macro avg       0.83      0.79      0.80       268
# weighted avg       0.82      0.81      0.81       268

# %%
gbc=GradientBoostingClassifier(n_estimators=100,learning_rate=0.01,max_depth=4,random_state=42)
gbc.fit(x__train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=4, random_state=42)

# %%
y_pred=gbc.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[145,  12],
#        [ 39,  72]])

# %%
gbc_t=accuracy_score(y_test,y_pred)*100
gbc_t
# Out:
# 80.97014925373134

# %%
print(gbc.score(x__train,y_train))
print(gbc.score(x_test,y_test))
# Out:
# 0.8426966292134831
# 0.8097014925373134

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       157
#            1       0.86      0.65      0.74       111
#
#     accuracy                           0.81       268
#    macro avg       0.82      0.79      0.79       268
# weighted avg       0.82      0.81      0.80       268

# %%
ada=AdaBoostClassifier(n_estimators=100,random_state=42)
ada.fit(x__train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_pred=ada.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[134,  23],
#        [ 28,  83]])

# %%
ada_t=accuracy_score(y_test,y_pred)*100
ada_t
# Out:
# 80.97014925373134

# %%
print(ada.score(x__train,y_train))
print(ada.score(x_test,y_test))
# Out:
# 0.8250401284109149
# 0.8097014925373134

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       157
#            1       0.78      0.75      0.76       111
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.80      0.80       268
# weighted avg       0.81      0.81      0.81       268

# %%
model1 = DecisionTreeClassifier(criterion = "entropy" ,max_depth=4 ,random_state= 42 )
model2 = GradientBoostingClassifier(n_estimators= 100, learning_rate=0.01, random_state=42 ,max_depth=4  , max_features=6 )
model3 = XGBClassifier(max_depth = 5 , learning_rate = 0.01 , n_estimators= 100, random_state=42)
model4 = RandomForestClassifier(n_estimators=100 ,criterion = 'entropy', max_depth=4, max_features=6 ,random_state=42)

# %%
v_clf = VotingClassifier(estimators=[("DecisionTreeClassifier" , model1) , ('GradientBoostingClassifier' , model2) ,
                                     ("XGBClassifier" , model3) ,("RandomForestClassifier" , model4)] , voting = "hard")

# %%
v_clf.fit(x__train , y_train)
# Out:
# VotingClassifier(estimators=[('DecisionTreeClassifier',
#                               DecisionTreeClassifier(criterion='entropy',
#                                                      max_depth=4,
#                                                      random_state=42)),
#                              ('GradientBoostingClassifier',
#                               GradientBoostingClassifier(learning_rate=0.01,
#                                                          max_depth=4,
#                                                          max_features=6,
#                                                          random_state=42)),
#                              ('XGBClassifier',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             col...
# ...

# %%
y_pred=v_clf.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[146,  11],
#        [ 39,  72]])

# %%
v_clf_t=accuracy_score(y_test,y_pred)*100
v_clf_t
# Out:
# 81.34328358208955

# %%
print(v_clf.score(x__train,y_train))
print(v_clf.score(x_test,y_test))
# Out:
# 0.841091492776886
# 0.8134328358208955

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       157
#            1       0.87      0.65      0.74       111
#
#     accuracy                           0.81       268
#    macro avg       0.83      0.79      0.80       268
# weighted avg       0.82      0.81      0.81       268

# %%
models_scores_tts={
    'KNN':knn_t,
    'Decision Tree':Dtx_t,
    'Random Forest':Rf_t,
    'Naive Bayes':NB_t,
    'Logistic Regression':LogR_t,
    'SVM':svm_t,
    'Gradient Boosting':gbc_t,
    'AdaBoost':ada_t,
    'XGBoost':xgb_t,
    'Voting Classifier':v_clf_t
}
df_scores_tts=pd.DataFrame(list(models_scores_tts.items()),columns=['Model','Score'])
df_scores_tts=df_scores_tts.sort_values(by='Score',ascending=False)
df_scores_tts
# Out:
#                  Model      Score
# 5                  SVM  82.089552
# 9    Voting Classifier  81.343284
# 8              XGBoost  81.343284
# 1        Decision Tree  80.970149
# 7             AdaBoost  80.970149
# 4  Logistic Regression  80.970149
# 6    Gradient Boosting  80.970149
# 2        Random Forest  80.597015
# 3          Naive Bayes  79.477612
# 0                  KNN  77.238806

# %%
print("\nComparison: ")
df_comparison=pd.merge(df_scores,df_scores_tts,on='Model',suffixes=('_cv','_tts'))
df_comparison[['Model', 'Score_cv', 'Score_tts']]
# Out:
# Comparison:
#                  Model  Score_cv  Score_tts
# 0        Random Forest     82.83  80.597015
# 1    Gradient Boosting     82.49  80.970149
# 2    Voting Classifier     82.38  81.343284
# 3              XGBoost     82.16  81.343284
# 4  Logistic Regression     81.93  80.970149
# 5                  SVM     81.82  82.089552
# 6        Decision Tree     81.48  80.970149
# 7             AdaBoost     81.03  80.970149
# 8                  KNN     80.92  77.238806
# 9          Naive Bayes     79.80  79.477612

# %%
clf3 = RandomForestClassifier(n_estimators=100 , criterion = "entropy" , max_depth= 5 ,random_state= 42)


clf3.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf3.predict(test_data)

# %%
submission=pd.DataFrame({'PassengerId':test['PassengerId'],'Survived':prediction})
submission.to_csv('submission.csv',index=False)

# %%
subm = pd.read_csv('submission.csv')
submission.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0
